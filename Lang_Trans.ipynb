# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip -q install -U \
  "opentelemetry-api==1.38.0" \
  "opentelemetry-sdk==1.38.0" \
  "opentelemetry-semantic-conventions==0.59b0" \
  "opentelemetry-exporter-otlp-proto-http==1.38.0"

# %%
import torch
import transformers
import mistralai

print("torch:", torch.__version__)
print("transformers:", transformers.__version__)
print("mistralai:", getattr(mistralai, "__version__", "ok"))

# sanity check: can we import the client class?
from mistralai.client import MistralClient
print("✅ MistralClient import OK")
""
# Out:
# torch: 2.10.0+cu128
# transformers: 4.38.2
# mistralai: ok
# ✅ MistralClient import OK
# ''

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from IndicTransToolkit import IndicProcessor

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("DEVICE:", DEVICE)

INDICTRANS_MODEL_ID = "ai4bharat/indictrans2-en-indic-1B"

indic_tokenizer = AutoTokenizer.from_pretrained(
    INDICTRANS_MODEL_ID,
    trust_remote_code=True
)

indic_model = AutoModelForSeq2SeqLM.from_pretrained(
    INDICTRANS_MODEL_ID,
    trust_remote_code=True,
    torch_dtype=torch.float16 if DEVICE == "cuda" else torch.float32,
    device_map="auto" if DEVICE == "cuda" else None
)

# NOTE: For non-quantized models, .to() is fine:
if DEVICE != "cuda":
    indic_model = indic_model.to(DEVICE)

indic_model.eval()

ip = IndicProcessor(inference=True)

print("✅ IndicTrans2 loaded")
# Out:
# DEVICE: cuda
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# ✅ IndicTrans2 loaded
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
LANG_CODE = {
    "hindi": "hin_Deva",
    "kannada": "kan_Knda",
    "tamil": "tam_Taml",
    "telugu": "tel_Telu",
    "malayalam": "mal_Mlym",
    "marathi": "mar_Deva",
    "bengali": "ben_Beng",
    "gujarati": "guj_Gujr",
    "punjabi": "pan_Guru",
    "odia": "ory_Orya",
}

def translate_with_indictrans(
    sentences,
    src_lang="eng_Latn",
    tgt_lang="hin_Deva",
    max_length=256,
    num_beams=5
):
    # 1) preprocess (required)
    batch = ip.preprocess_batch(sentences, src_lang=src_lang, tgt_lang=tgt_lang, visualize=False)

    # 2) tokenize
    inputs = indic_tokenizer(
        batch,
        truncation=True,
        padding="longest",
        max_length=max_length,
        return_tensors="pt",
        return_attention_mask=True
    ).to(DEVICE)

    # 3) generate
    with torch.inference_mode():
        generated = indic_model.generate(
            **inputs,
            use_cache=True,
            min_length=0,
            max_length=max_length,
            num_beams=num_beams,
            num_return_sequences=1
        )

    # 4) decode + postprocess
    decoded = indic_tokenizer.batch_decode(
        generated,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=True
    )
    out = ip.postprocess_batch(decoded, lang=tgt_lang)
    return out

# %%
# !pip -q install -U "mistralai==0.4.2"

# %%
import re
from mistralai.client import MistralClient
from mistralai.models.chat_completion import ChatMessage

# --- API key (recommended: Colab Secret) ---
try:
    from google.colab import userdata
    MISTRAL_API_KEY = userdata.get("MISTRAL_API_KEY")
except Exception:
    MISTRAL_API_KEY = None

if not MISTRAL_API_KEY:
    raise ValueError("❌ Set MISTRAL_API_KEY in Colab Secrets")

mistral = MistralClient(api_key=MISTRAL_API_KEY)
MISTRAL_MODEL = "mistral-large-latest"

# --- strict, rewrite-only prompt ---
NORMALIZER_SYSTEM = """You are a semantic normalizer for translation.

Rewrite the user's message into clear, grammatical English.

Hard rules:
- Never refuse. Never ask questions.
- Do NOT add new facts, times, places, names, or numbers.
- Expand slang/abbreviations/idioms into standard English.
- Keep any non-English words exactly as they appear (do not translate them).
- Preserve question/statement form and sentiment (anger/sarcasm).
- Output ONLY the rewritten text. No explanations, no labels.
"""

def _clean_out(text: str) -> str:
    text = text.strip()
    text = re.sub(r"^(assistant|Assistant)\s*[:\-]?\s*", "", text)
    text = re.sub(r"\s+", " ", text)
    return text.strip()

def normalize_with_mistral_api(user_text: str) -> str:
    resp = mistral.chat(
        model=MISTRAL_MODEL,
        messages=[
            ChatMessage(role="system", content=NORMALIZER_SYSTEM),
            ChatMessage(role="user", content=user_text),
        ],
        temperature=0.0,
        max_tokens=128,
    )
    return _clean_out(resp.choices[0].message.content)

print("✅ Stage-1 normalizer ready (mistral-large-latest via API)")
# Out:
# ✅ Stage-1 normalizer ready (mistral-large-latest via API)

# %%
def agentic_translate(user_text: str, target_language: str):
    target_language = target_language.lower()
    if target_language not in LANG_CODE:
        raise ValueError(f"Unsupported target_language: {target_language}. Choose from: {list(LANG_CODE.keys())}")

    # Stage 1: normalize via Mistral API
    normalized = normalize_with_mistral_api(user_text)

    # Stage 2: translate locally via IndicTrans2
    tgt_code = LANG_CODE[target_language]
    translated = translate_with_indictrans(
        [normalized],
        src_lang="eng_Latn",
        tgt_lang=tgt_code
    )[0]

    return {
        "input": user_text,
        "normalized_english": normalized,
        "target_language": target_language,
        "translation": translated
    }

# -----------------------
# End-to-end stress tests
# -----------------------
stress_tests = [
    ("idk bro, this weather is wild af, raining cats and dogs fr", "kannada"),
    ("ivathu office hogbeku illa antha doubt, manager call madthara?", "kannada"),
    ("wah bhai, server firse down hai, amazing service 👏👏", "hindi"),
    ("why this app always crash when i need it most 😡", "tamil"),
    ("ngl this update kinda slaps but battery drain is crazy", "telugu"),
    ("can u pls check and let me know by eod, super urgent", "marathi"),
    ("meeting today or tomorrow?", "kannada"),
    ("kal meeting 3pm irukku right?", "tamil"),
    ("please do the needful asap", "hindi"),
]

for text, lang in stress_tests:
    print("=" * 90)
    out = agentic_translate(text, lang)
    print("INPUT:      ", out["input"])
    print("NORMALIZED: ", out["normalized_english"])
    print("TRANSLATED: ", out["translation"])
# Out:
# ==========================================================================================
# INPUT:       idk bro, this weather is wild af, raining cats and dogs fr
# NORMALIZED:  I don't know, this weather is extremely unpredictable—it's raining very heavily right now.
# TRANSLATED:  ನನಗೆ ಗೊತ್ತಿಲ್ಲ, ಈ ಹವಾಮಾನವು ಅತ್ಯಂತ ಅನಿರೀಕ್ಷಿತವಾಗಿದೆ-ಈಗ ಭಾರೀ ಮಳೆಯಾಗುತ್ತಿದೆ.
# ==========================================================================================
# INPUT:       ivathu office hogbeku illa antha doubt, manager call madthara?
# NORMALIZED:  I don't need to come to the office, right? That was my doubt, so I called the manager.
# TRANSLATED:  ನಾನು ಕಚೇರಿಗೆ ಬರಬೇಕಾಗಿಲ್ಲ, ಅಲ್ಲವೇ? ಅದು ನನ್ನ ಅನುಮಾನವಾಗಿತ್ತು, ಆದ್ದರಿಂದ ನಾನು ಮ್ಯಾನೇಜರ್ಗೆ ಕರೆ ಮಾಡಿದೆ.
# ==========================================================================================
# INPUT:       wah bhai, server firse down hai, amazing service 👏👏
# NORMALIZED:  Oh man, the server is down again. What amazing service.
# TRANSLATED:  ओह यार, सर्वर फिर से डाउन हो गया है। क्या अद्भुत सेवा है।
# ==========================================================================================
# INPUT:       why this app always crash when i need it most 😡
# NORMALIZED:  This application keeps crashing whenever I need it the most.
# TRANSLATED:  எனக்கு மிகவும் தேவைப்படும் போதெல்லாம் இந்த பயன்பாடு செயலிழந்து கொண்டே இருக்கும்.
# ==========================================================================================
# INPUT:       ngl this update kinda slaps but battery drain is crazy
# NORMALIZED:  To be honest, this update is actually quite good, but the battery consumption is excessive.
# TRANSLATED:  నిజాయితీగా చెప్పాలంటే, ఈ నవీకరణ నిజానికి చాలా బాగుంది, కానీ బ్యాటరీ వినియోగం అధికంగా ఉంటుంది.
# ==========================================================================================
# INPUT:       can u pls check and let me know by eod, super urgent
# NORMALIZED:  Please check this and let me know by the end of the day—it is very urgent.
# TRANSLATED:  कृपया हे तपासा आणि दिवसाच्या अखेरीस मला कळवा-हे खूप तातडीचे आहे.
# ==========================================================================================
# INPUT:       meeting today or tomorrow?
# NORMALIZED:  Should we have the meeting today or tomorrow?
# TRANSLATED:  ನಾವು ಇಂದು ಅಥವಾ ನಾಳೆ ಸಭೆ ನಡೆಸಬೇಕೇ?
# ==========================================================================================
# INPUT:       kal meeting 3pm irukku right?
# NORMALIZED:  The meeting is scheduled for 3 PM, correct?
# TRANSLATED:  கூட்டம் பிற்பகல் 3 மணிக்கு திட்டமிடப்பட்டுள்ளது, இல்லையா?
# ==========================================================================================
# INPUT:       please do the needful asap
# NORMALIZED:  Please take the necessary action as soon as possible.
# TRANSLATED:  कृपया जल्द से जल्द आवश्यक कार्रवाई करें।

# %%
import random
import time

# -----------------------------
# 120+ Stress Test Cases
# Format: (input_text, target_language)
# -----------------------------
STRESS_TESTS_120 = [
    # --- slang + idioms ---
    ("idk man, it's raining cats and dogs", "hindi"),
    ("bruh this is wild af", "kannada"),
    ("ngl that was kinda mid", "tamil"),
    ("fr this app slaps", "telugu"),
    ("lowkey I'm done with this", "marathi"),
    ("highkey this is annoying", "bengali"),
    ("I'm over the moon right now", "hindi"),
    ("this is the last straw", "kannada"),
    ("spill the tea, what happened?", "tamil"),
    ("no cap, that's impressive", "telugu"),
    ("that’s a piece of cake", "marathi"),
    ("break a leg for your interview", "bengali"),
    ("hit the sack, I'm tired", "hindi"),
    ("it's not my cup of tea", "kannada"),
    ("once in a blue moon", "tamil"),
    ("costs an arm and a leg", "telugu"),
    ("I'm feeling under the weather", "marathi"),
    ("let's call it a day", "bengali"),
    ("that's the icing on the cake", "hindi"),
    ("I'm on the same page as you", "kannada"),

    # --- sarcasm / passive aggression ---
    ("wow amazing service, server down again 👏", "hindi"),
    ("great, another bug. just what I needed.", "tamil"),
    ("nice. very nice. nothing works.", "kannada"),
    ("sure, take your time... it's not urgent at all 🙃", "telugu"),
    ("love how it crashes exactly when I click submit", "marathi"),
    ("fantastic, payment failed for the third time", "bengali"),
    ("yeah right, 'quick fix' my foot", "hindi"),
    ("super smooth experience... said no one ever", "kannada"),
    ("oh perfect, now it's stuck on loading forever", "tamil"),
    ("thanks for nothing", "telugu"),

    # --- broken English / typos / phonetic ---
    ("plz do needful asap", "hindi"),
    ("cant login, pw reset not working", "kannada"),
    ("u check once and tell", "tamil"),
    ("i no understand why error coming", "telugu"),
    ("app crash when open only", "marathi"),
    ("net slow so msg late", "bengali"),
    ("its showing invalid otp again n again", "hindi"),
    ("payment done but not reflecting", "kannada"),
    ("order cancelled but money not back", "tamil"),
    ("screen freeze after update", "telugu"),
    ("why my account lock??", "marathi"),
    ("pls share update by eod", "bengali"),

    # --- time / constraints (important: no hallucinations) ---
    ("please respond by EOD", "hindi"),
    ("need this done by 5 pm today", "kannada"),
    ("schedule it for tomorrow morning", "tamil"),
    ("move the meeting to next Monday", "telugu"),
    ("remind me in 2 hours", "marathi"),
    ("call me at 10:30 am", "bengali"),
    ("submit before 23:59 today", "hindi"),
    ("we need the report by end of day", "kannada"),
    ("deliver it in 15 minutes", "tamil"),
    ("do it ASAP", "telugu"),

    # --- code-mix: Hinglish ---
    ("bhai kal meeting hai kya?", "hindi"),
    ("yaar server firse down ho gaya", "hindi"),
    ("pls thoda jaldi karo, urgent hai", "hindi"),
    ("mera payment stuck hai, check karo", "hindi"),
    ("aaj call kar sakte ho kya?", "hindi"),
    ("thanks bhai, but issue abhi bhi hai", "hindi"),
    ("boss ko message bhej du kya?", "hindi"),
    ("OTP nahi aa raha, kya karu?", "hindi"),
    ("kal 3 baje meeting fix hai na?", "hindi"),
    ("kya scene hai? app open nahi ho raha", "hindi"),

    # --- code-mix: Kanglish ---
    ("naale meeting reschedule madana? please confirm", "kannada"),
    ("ivathu office hogbeku illa antha doubt, manager call madthara?", "kannada"),
    ("bro swalpa adjust maadi, urgent ide", "kannada"),
    ("payment aagide but receipt baralla", "kannada"),
    ("ninna night app hang aitu", "kannada"),
    ("data load aagtha illa, yen madbeku?", "kannada"),
    ("meeting ge late aagutte, sorry", "kannada"),
    ("kelsa complete madidini, pls review", "kannada"),
    ("naan barthini, but swalpa late", "kannada"),
    ("call maadi, important", "kannada"),

    # --- code-mix: Tanglish ---
    ("kal meeting 3pm irukku right?", "tamil"),
    ("innaiku office poganuma? manager call pannuvana?", "tamil"),
    ("bro konjam wait pannunga, net slow", "tamil"),
    ("payment pannen but status update aagala", "tamil"),
    ("app open panna crash aaguthu", "tamil"),
    ("naan late aaguren, sorry", "tamil"),
    ("please confirm meeting naale iruka?", "tamil"),
    ("enaku OTP varala, help pannunga", "tamil"),
    ("ticket raise panniten, reply varala", "tamil"),
    ("server down ah? romba worst", "tamil"),

    # --- mixed punctuation / noise ---
    ("HELLO??? any update??!!", "hindi"),
    ("whattttt is thisssss 😭😭", "kannada"),
    (".............", "tamil"),
    ("ok fine whatever", "telugu"),
    ("BROOOOOOOOOOO", "marathi"),
    ("??!!??", "bengali"),
    ("pls..... fix..... now.....", "hindi"),
    ("why??????", "kannada"),
    ("it works... then it doesn't...", "tamil"),
    ("hmmm idk", "telugu"),

    # --- support / business-style ---
    ("Could you please provide an update on the ticket status?", "hindi"),
    ("We are blocked due to this issue. Please prioritize.", "kannada"),
    ("Kindly share the RCA once available.", "tamil"),
    ("Please confirm the deployment timeline.", "telugu"),
    ("We need the ETA for resolution.", "marathi"),
    ("The issue is reproducible on version 2.1.3.", "bengali"),
    ("Please escalate this to the engineering team.", "hindi"),
    ("We observed intermittent failures in production.", "kannada"),
    ("The customer is waiting; please respond ASAP.", "tamil"),
    ("Let’s align on next steps.", "telugu"),

    # --- negation / tricky semantics ---
    ("I didn't say it was not working.", "hindi"),
    ("It's not that I can't login, it's that it logs me out.", "kannada"),
    ("Don't reschedule the meeting.", "tamil"),
    ("Please don't cancel the order.", "telugu"),
    ("I never received the OTP, not even once.", "marathi"),
    ("This isn't good, but it's not terrible either.", "bengali"),
    ("I don't want a refund, I want a fix.", "hindi"),
    ("Not today, maybe tomorrow.", "kannada"),
    ("No, I didn't approve that change.", "tamil"),
    ("I can't not respond by EOD.", "telugu"),

    # --- edge: very short ---
    ("ok", "hindi"),
    ("no", "kannada"),
    ("yes", "tamil"),
    ("urgent", "telugu"),
    ("done", "marathi"),
    ("help", "bengali"),
]

# Ensure at least 120 (we already have >120, but keep deterministic)
random.seed(42)
random.shuffle(STRESS_TESTS_120)

print("Total test cases:", len(STRESS_TESTS_120))

# -----------------------------
# Runner: batch + rate-friendly
# -----------------------------
def run_stress_tests(tests, batch_size=10, sleep_s=1.0):
    """
    Stage-1 uses Mistral API (per item), Stage-2 is local.
    We batch only for display pacing, not for API batching.
    """
    results = []
    for i in range(0, len(tests), batch_size):
        batch = tests[i:i+batch_size]
        print("\n" + "#" * 100)
        print(f"Batch {i//batch_size + 1} | cases {i+1}-{min(i+batch_size, len(tests))}")
        print("#" * 100)

        for text, lang in batch:
            try:
                out = agentic_translate(text, lang)
                results.append(out)
                print("-" * 90)
                print("INPUT:      ", out["input"])
                print("NORMALIZED: ", out["normalized_english"])
                print("LANG:       ", out["target_language"])
                print("TRANSLATED: ", out["translation"])
            except Exception as e:
                results.append({"input": text, "target_language": lang, "error": str(e)})
                print("-" * 90)
                print("INPUT: ", text)
                print("LANG:  ", lang)
                print("ERROR: ", e)

        # small pause to reduce API burstiness
        time.sleep(sleep_s)

    return results

# Run all 120+ tests
stress_results = run_stress_tests(STRESS_TESTS_120, batch_size=8, sleep_s=0.6)

print("\n✅ Finished. Results stored in: stress_results")
# Out:
# Total test cases: 118
#
# ####################################################################################################
# Batch 1 | cases 1-8
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       meeting ge late aagutte, sorry
# NORMALIZED:  I arrived late to the meeting, I apologize.
# LANG:        kannada
# TRANSLATED:  ನಾನು ಸಭೆಗೆ ತಡವಾಗಿ ಬಂದಿದ್ದೇನೆ, ನಾನು ಕ್ಷಮೆಯಾಚಿಸುತ್ತೇನೆ.
# ------------------------------------------------------------------------------------------
# INPUT:       ok
# NORMALIZED:  Alright.
# LANG:        hindi
# TRANSLATED:  ठीक है।
# ------------------------------------------------------------------------------------------
# INPUT:       HELLO??? any update??!!
# NORMALIZED:  Hello? Is there any update?
# LANG:        hindi
# TRANSLATED:  नमस्ते? क्या कोई अद्यतन जानकारी है?
# ------------------------------------------------------------------------------------------
# INPUT:       deliver it in 15 minutes
# NORMALIZED:  Get it delivered within fifteen minutes.
# LANG:        tamil
# TRANSLATED:  பதினைந்து நிமிடங்களுக்குள் அதை டெலிவரி செய்யுங்கள்.
# ------------------------------------------------------------------------------------------
# INPUT:       pls share update by eod
# NORMALIZED:  Please provide the update by the end of the day.
# LANG:        bengali
# TRANSLATED:  দয়া করে দিনের শেষে আপডেট প্রদান করুন।
# ------------------------------------------------------------------------------------------
# INPUT:       I'm feeling under the weather
# NORMALIZED:  I am not feeling well.
# LANG:        marathi
# TRANSLATED:  मला बरे वाटत नाही.
# ------------------------------------------------------------------------------------------
# INPUT:       .............
# NORMALIZED:  I can't understand what you're trying to say. Please provide a clearer message.
# LANG:        tamil
# TRANSLATED:  நீங்கள் என்ன சொல்ல முயற்சிக்கிறீர்கள் என்று எனக்கு புரியவில்லை. தயவுசெய்து ஒரு தெளிவான செய்தியை வழங்கவும்.
# ------------------------------------------------------------------------------------------
# INPUT:       pls..... fix..... now.....
# NORMALIZED:  Please fix this immediately.
# LANG:        hindi
# TRANSLATED:  कृपया इसे तुरंत ठीक करें।
#
# ####################################################################################################
# Batch 2 | cases 9-16
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       Please confirm the deployment timeline.
# NORMALIZED:  Please verify the schedule for the deployment.
# LANG:        telugu
# TRANSLATED:  దయచేసి విస్తరణ కోసం షెడ్యూల్ను ధృవీకరించండి.
# ------------------------------------------------------------------------------------------
# INPUT:       naale meeting reschedule madana? please confirm
# NORMALIZED:  Could you please reschedule today's meeting? Please confirm.
# LANG:        kannada
# TRANSLATED:  ನೀವು ದಯವಿಟ್ಟು ಇಂದಿನ ಸಭೆಯನ್ನು ಮರು ನಿಗದಿಪಡಿಸಬಹುದೇ? ದಯವಿಟ್ಟು ದೃಢೀಕರಿಸಿ.
# ------------------------------------------------------------------------------------------
# INPUT:       plz do needful asap
# NORMALIZED:  Please complete the necessary tasks as soon as possible.
# LANG:        hindi
# TRANSLATED:  कृपया आवश्यक कार्यों को जल्द से जल्द पूरा करें।
# ------------------------------------------------------------------------------------------
# INPUT:       innaiku office poganuma? manager call pannuvana?
# NORMALIZED:  Did you go to the office today? Is the manager going to call?
# LANG:        tamil
# TRANSLATED:  நீங்கள் இன்று அலுவலகத்திற்குச் சென்றீர்களா? மேலாளர் அழைக்கப் போகிறாரா?
# ------------------------------------------------------------------------------------------
# INPUT:       no cap, that's impressive
# NORMALIZED:  Honestly, that is truly impressive.
# LANG:        telugu
# TRANSLATED:  నిజాయితీగా చెప్పాలంటే, ఇది నిజంగా ఆకట్టుకునేలా ఉంది.
# ------------------------------------------------------------------------------------------
# INPUT:       I never received the OTP, not even once.
# NORMALIZED:  I did not receive the one-time password at any point.
# LANG:        marathi
# TRANSLATED:  मला कोणत्याही क्षणी वन-टाइम पासवर्ड मिळाला नाही.
# ------------------------------------------------------------------------------------------
# INPUT:       call me at 10:30 am
# NORMALIZED:  Call me at 10:30 in the morning.
# LANG:        bengali
# TRANSLATED:  আমাকে সকালে 10:30-এ কল করুন।
# ------------------------------------------------------------------------------------------
# INPUT:       app open panna crash aaguthu
# NORMALIZED:  The application keeps crashing when I try to open it.
# LANG:        tamil
# TRANSLATED:  நான் அதைத் திறக்க முயற்சிக்கும்போது பயன்பாடு செயலிழந்து கொண்டே இருக்கும்.
#
# ####################################################################################################
# Batch 3 | cases 17-24
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       This isn't good, but it's not terrible either.
# NORMALIZED:  This is not ideal, but it is not completely bad either.
# LANG:        bengali
# TRANSLATED:  এটি আদর্শ নয়, তবে এটি সম্পূর্ণ খারাপও নয়।
# ------------------------------------------------------------------------------------------
# INPUT:       Could you please provide an update on the ticket status?
# NORMALIZED:  Could you please give me an update on the current status of the ticket?
# LANG:        hindi
# TRANSLATED:  क्या आप कृपया मुझे टिकट की वर्तमान स्थिति के बारे में जानकारी दे सकते हैं?
# ------------------------------------------------------------------------------------------
# INPUT:       yeah right, 'quick fix' my foot
# NORMALIZED:  Oh sure, like that so-called "quick fix" is actually going to work.
# LANG:        hindi
# TRANSLATED:  ओह निश्चित रूप से, उस तथाकथित "त्वरित सुधार" की तरह वास्तव में काम करने वाला है।
# ------------------------------------------------------------------------------------------
# INPUT:       payment done but not reflecting
# NORMALIZED:  The payment has been made, but it is not showing up.
# LANG:        kannada
# TRANSLATED:  ಪಾವತಿ ಮಾಡಲಾಗಿದೆ, ಆದರೆ ಅದು ಕಾಣುತ್ತಿಲ್ಲ.
# ------------------------------------------------------------------------------------------
# INPUT:       bruh this is wild af
# NORMALIZED:  This situation is incredibly surprising.
# LANG:        kannada
# TRANSLATED:  ಈ ಪರಿಸ್ಥಿತಿಯು ನಂಬಲಾಗದಷ್ಟು ಆಶ್ಚರ್ಯಕರವಾಗಿದೆ.
# ------------------------------------------------------------------------------------------
# INPUT:       u check once and tell
# NORMALIZED:  Please review this once and let me know.
# LANG:        tamil
# TRANSLATED:  தயவுசெய்து இதை ஒரு முறை மதிப்பாய்வு செய்து எனக்குத் தெரியப்படுத்துங்கள்.
# ------------------------------------------------------------------------------------------
# INPUT:       great, another bug. just what I needed.
# NORMALIZED:  Fantastic, there is another issue. Exactly what I wanted.
# LANG:        tamil
# TRANSLATED:  அருமை, இன்னொரு பிரச்சினையும் உள்ளது. அதைத்தான் நான் விரும்பினேன்.
# ------------------------------------------------------------------------------------------
# INPUT:       this is the last straw
# NORMALIZED:  This is absolutely unacceptable.
# LANG:        kannada
# TRANSLATED:  ಇದು ಸಂಪೂರ್ಣವಾಗಿ ಸ್ವೀಕಾರಾರ್ಹವಲ್ಲ.
#
# ####################################################################################################
# Batch 4 | cases 25-32
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       app crash when open only
# NORMALIZED:  The application crashes whenever I try to open it.
# LANG:        marathi
# TRANSLATED:  जेव्हा जेव्हा मी ते उघडण्याचा प्रयत्न करतो तेव्हा अनुप्रयोग क्रॅश होतो.
# ------------------------------------------------------------------------------------------
# INPUT:       ticket raise panniten, reply varala
# NORMALIZED:  I have raised a ticket, but there has been no response.
# LANG:        tamil
# TRANSLATED:  நான் டிக்கெட் எடுத்துள்ளேன், ஆனால் எந்த பதிலும் இல்லை.
# ------------------------------------------------------------------------------------------
# INPUT:       help
# NORMALIZED:  I need assistance.
# LANG:        bengali
# TRANSLATED:  আমার সাহায্য দরকার।
# ------------------------------------------------------------------------------------------
# INPUT:       spill the tea, what happened?
# NORMALIZED:  Do tell, what occurred?
# LANG:        tamil
# TRANSLATED:  சொல்லுங்கள், என்ன நடந்தது?
# ------------------------------------------------------------------------------------------
# INPUT:       kal 3 baje meeting fix hai na?
# NORMALIZED:  The meeting is confirmed for three o'clock tomorrow, right?
# LANG:        hindi
# TRANSLATED:  कल तीन बजे के लिए बैठक की पुष्टि हो गई है, है ना?
# ------------------------------------------------------------------------------------------
# INPUT:       bhai kal meeting hai kya?
# NORMALIZED:  Is there a meeting tomorrow, brother?
# LANG:        hindi
# TRANSLATED:  कल कोई मीटिंग है, भाई?
# ------------------------------------------------------------------------------------------
# INPUT:       remind me in 2 hours
# NORMALIZED:  Remind me in two hours.
# LANG:        marathi
# TRANSLATED:  दोन तासांत मला आठवण करून द्या.
# ------------------------------------------------------------------------------------------
# INPUT:       payment aagide but receipt baralla
# NORMALIZED:  The payment has been made, but the receipt is not available.
# LANG:        kannada
# TRANSLATED:  ಪಾವತಿ ಮಾಡಲಾಗಿದೆ, ಆದರೆ ರಸೀದಿ ಲಭ್ಯವಿಲ್ಲ.
#
# ####################################################################################################
# Batch 5 | cases 33-40
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       order cancelled but money not back
# NORMALIZED:  The order was canceled, but the money has not been refunded.
# LANG:        tamil
# TRANSLATED:  ஆர்டர் ரத்து செய்யப்பட்டது, ஆனால் பணம் திருப்பித் தரப்படவில்லை.
# ------------------------------------------------------------------------------------------
# INPUT:       do it ASAP
# NORMALIZED:  Complete it as soon as possible.
# LANG:        telugu
# TRANSLATED:  వీలైనంత త్వరగా దాన్ని పూర్తి చేయండి.
# ------------------------------------------------------------------------------------------
# INPUT:       we need the report by end of day
# NORMALIZED:  We need the report completed by the end of the day.
# LANG:        kannada
# TRANSLATED:  ದಿನದ ಅಂತ್ಯದ ವೇಳೆಗೆ ವರದಿಯನ್ನು ಪೂರ್ಣಗೊಳಿಸಬೇಕಾಗಿದೆ.
# ------------------------------------------------------------------------------------------
# INPUT:       bro konjam wait pannunga, net slow
# NORMALIZED:  Hey brother, please wait a little while, the internet is slow.
# LANG:        tamil
# TRANSLATED:  ஏய் சகோதரரே, தயவுசெய்து சிறிது நேரம் காத்திருங்கள், இணையம் மெதுவாக உள்ளது.
# ------------------------------------------------------------------------------------------
# INPUT:       nice. very nice. nothing works.
# NORMALIZED:  Great. That's just fantastic. Nothing is functioning.
# LANG:        kannada
# TRANSLATED:  ಗ್ರೇಟ್. ಇದು ಕೇವಲ ಅದ್ಭುತವಾಗಿದೆ. ಏನೂ ಕೆಲಸ ಮಾಡುತ್ತಿಲ್ಲ.
# ------------------------------------------------------------------------------------------
# INPUT:       ninna night app hang aitu
# NORMALIZED:  The app keeps freezing every night.
# LANG:        kannada
# TRANSLATED:  ಈ ಅಪ್ಲಿಕೇಶನ್ ಪ್ರತಿ ರಾತ್ರಿ ಫ್ರೀಜ್ ಆಗುತ್ತಿರುತ್ತದೆ.
# ------------------------------------------------------------------------------------------
# INPUT:       ivathu office hogbeku illa antha doubt, manager call madthara?
# NORMALIZED:  I need to go to the office, but I have that doubt—will the manager call me?
# LANG:        kannada
# TRANSLATED:  ನಾನು ಕಚೇರಿಗೆ ಹೋಗಬೇಕು, ಆದರೆ ನನಗೆ ಆ ಅನುಮಾನವಿದೆ-ಮ್ಯಾನೇಜರ್ ನನಗೆ ಕರೆ ಮಾಡುತ್ತಾರೆಯೇ?
# ------------------------------------------------------------------------------------------
# INPUT:       ok fine whatever
# NORMALIZED:  Alright, I suppose that will do.
# LANG:        telugu
# TRANSLATED:  సరే, అది జరుగుతుందని నేను అనుకుంటున్నాను.
#
# ####################################################################################################
# Batch 6 | cases 41-48
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       OTP nahi aa raha, kya karu?
# NORMALIZED:  I'm not receiving the one-time password. What should I do?
# LANG:        hindi
# TRANSLATED:  मुझे वन-टाइम पासवर्ड नहीं मिल रहा है। मुझे क्या करना चाहिए?
# ------------------------------------------------------------------------------------------
# INPUT:       The issue is reproducible on version 2.1.3.
# NORMALIZED:  The problem can be replicated in version 2.1.3.
# LANG:        bengali
# TRANSLATED:  সমস্যাটি সংস্করণ 2.1.3-এ প্রতিলিপি করা যেতে পারে।
# ------------------------------------------------------------------------------------------
# INPUT:       No, I didn't approve that change.
# NORMALIZED:  No, I did not authorize that modification.
# LANG:        tamil
# TRANSLATED:  இல்லை, அந்த மாற்றத்திற்கு நான் அங்கீகாரம் அளிக்கவில்லை.
# ------------------------------------------------------------------------------------------
# INPUT:       love how it crashes exactly when I click submit
# NORMALIZED:  I really dislike that it fails right when I try to submit.
# LANG:        marathi
# TRANSLATED:  जेव्हा मी सादर करण्याचा प्रयत्न करतो तेव्हा ते योग्यरित्या अयशस्वी होते हे मला खरोखर आवडत नाही.
# ------------------------------------------------------------------------------------------
# INPUT:       I'm over the moon right now
# NORMALIZED:  I am extremely happy at this moment.
# LANG:        hindi
# TRANSLATED:  मैं इस समय बहुत खुश हूं।
# ------------------------------------------------------------------------------------------
# INPUT:       We need the ETA for resolution.
# NORMALIZED:  We need to know when this will be resolved.
# LANG:        marathi
# TRANSLATED:  हे केव्हा सोडवले जाईल हे आपल्याला माहित असणे आवश्यक आहे.
# ------------------------------------------------------------------------------------------
# INPUT:       data load aagtha illa, yen madbeku?
# NORMALIZED:  I don't have the data loaded, what do I need?
# LANG:        kannada
# TRANSLATED:  ನಾನು ಡೇಟಾವನ್ನು ಲೋಡ್ ಮಾಡಿಲ್ಲ, ನನಗೆ ಏನು ಬೇಕು?
# ------------------------------------------------------------------------------------------
# INPUT:       kya scene hai? app open nahi ho raha
# NORMALIZED:  What is happening? The application is not opening.
# LANG:        hindi
# TRANSLATED:  क्या हो रहा है? अनुप्रयोग नहीं खुल रहा है।
#
# ####################################################################################################
# Batch 7 | cases 49-56
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       done
# NORMALIZED:  Finished.
# LANG:        marathi
# TRANSLATED:  पूर्ण झाले.
# ------------------------------------------------------------------------------------------
# INPUT:       please respond by EOD
# NORMALIZED:  Please respond by the end of the day.
# LANG:        hindi
# TRANSLATED:  कृपया दिन के अंत तक जवाब दें।
# ------------------------------------------------------------------------------------------
# INPUT:       ngl that was kinda mid
# NORMALIZED:  To be honest, that was somewhat mediocre.
# LANG:        tamil
# TRANSLATED:  உண்மையைச் சொல்வதானால், அது ஓரளவு சாதாரணமாக இருந்தது.
# ------------------------------------------------------------------------------------------
# INPUT:       Let’s align on next steps.
# NORMALIZED:  Let's agree on the next steps.
# LANG:        telugu
# TRANSLATED:  తదుపరి దశలపై ఏకాభిప్రాయానికి వద్దాం.
# ------------------------------------------------------------------------------------------
# INPUT:       naan barthini, but swalpa late
# NORMALIZED:  I did not understand, but it was a little late.
# LANG:        kannada
# TRANSLATED:  ನನಗೆ ಅರ್ಥವಾಗಲಿಲ್ಲ, ಆದರೆ ಸ್ವಲ್ಪ ತಡವಾಗಿತ್ತು.
# ------------------------------------------------------------------------------------------
# INPUT:       We are blocked due to this issue. Please prioritize.
# NORMALIZED:  We are currently unable to proceed because of this problem. Please address it as a priority.
# LANG:        kannada
# TRANSLATED:  ಈ ಸಮಸ್ಯೆಯಿಂದಾಗಿ ನಾವು ಪ್ರಸ್ತುತ ಮುಂದುವರಿಯಲು ಸಾಧ್ಯವಾಗುತ್ತಿಲ್ಲ. ದಯವಿಟ್ಟು ಇದನ್ನು ಆದ್ಯತೆಯಾಗಿ ಪರಿಗಣಿಸಿ.
# ------------------------------------------------------------------------------------------
# INPUT:       its showing invalid otp again n again
# NORMALIZED:  It keeps displaying an invalid one-time password repeatedly.
# LANG:        hindi
# TRANSLATED:  यह बार-बार अमान्य वन-टाइम पासवर्ड प्रदर्शित करता रहता है।
# ------------------------------------------------------------------------------------------
# INPUT:       sure, take your time... it's not urgent at all 🙃
# NORMALIZED:  Of course, there is no need to hurry—it is not at all urgent.
# LANG:        telugu
# TRANSLATED:  వాస్తవానికి, తొందరపడాల్సిన అవసరం లేదు-ఇది అస్సలు అత్యవసరం కాదు.
#
# ####################################################################################################
# Batch 8 | cases 57-64
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       mera payment stuck hai, check karo
# NORMALIZED:  My payment is stuck, please check it.
# LANG:        hindi
# TRANSLATED:  मेरा भुगतान अटक गया है, कृपया इसे देखें।
# ------------------------------------------------------------------------------------------
# INPUT:       aaj call kar sakte ho kya?
# NORMALIZED:  Can you call today?
# LANG:        hindi
# TRANSLATED:  क्या आप आज फोन कर सकते हैं?
# ------------------------------------------------------------------------------------------
# INPUT:       screen freeze after update
# NORMALIZED:  The screen freezes after the update.
# LANG:        telugu
# TRANSLATED:  నవీకరణ తర్వాత తెర స్తంభింపజేయబడుతుంది.
# ------------------------------------------------------------------------------------------
# INPUT:       why my account lock??
# NORMALIZED:  Why was my account locked?
# LANG:        marathi
# TRANSLATED:  माझे खाते का बंद करण्यात आले?
# ------------------------------------------------------------------------------------------
# INPUT:       ??!!??
# NORMALIZED:  What on earth is going on?!
# LANG:        bengali
# TRANSLATED:  পৃথিবীতে কী ঘটছে?!
# ------------------------------------------------------------------------------------------
# INPUT:       that's the icing on the cake
# NORMALIZED:  That is the perfect finishing touch.
# LANG:        hindi
# TRANSLATED:  यह एकदम सही परिष्करण स्पर्श है।
# ------------------------------------------------------------------------------------------
# INPUT:       please confirm meeting naale iruka?
# NORMALIZED:  Please confirm if the meeting is happening tomorrow.
# LANG:        tamil
# TRANSLATED:  நாளை கூட்டம் நடக்கிறதா என்பதை தயவுசெய்து உறுதிப்படுத்தவும்.
# ------------------------------------------------------------------------------------------
# INPUT:       that’s a piece of cake
# NORMALIZED:  That is very easy.
# LANG:        marathi
# TRANSLATED:  हे खूप सोपे आहे.
#
# ####################################################################################################
# Batch 9 | cases 65-72
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       kal meeting 3pm irukku right?
# NORMALIZED:  The meeting is scheduled for 3 PM, correct?
# LANG:        tamil
# TRANSLATED:  கூட்டம் பிற்பகல் 3 மணிக்கு திட்டமிடப்பட்டுள்ளது, இல்லையா?
# ------------------------------------------------------------------------------------------
# INPUT:       costs an arm and a leg
# NORMALIZED:  It is extremely expensive.
# LANG:        telugu
# TRANSLATED:  ఇది చాలా ఖరీదైనది.
# ------------------------------------------------------------------------------------------
# INPUT:       boss ko message bhej du kya?
# NORMALIZED:  Should I send a message to the boss?
# LANG:        hindi
# TRANSLATED:  क्या मुझे बॉस को संदेश भेजना चाहिए?
# ------------------------------------------------------------------------------------------
# INPUT:       highkey this is annoying
# NORMALIZED:  This is genuinely quite frustrating.
# LANG:        bengali
# TRANSLATED:  এটা সত্যিই বেশ হতাশাজনক।
# ------------------------------------------------------------------------------------------
# INPUT:       i no understand why error coming
# NORMALIZED:  I do not understand why the error is occurring.
# LANG:        telugu
# TRANSLATED:  ఈ పొరపాటు ఎందుకు జరుగుతోందో నాకు అర్థం కావడం లేదు.
# ------------------------------------------------------------------------------------------
# INPUT:       schedule it for tomorrow morning
# NORMALIZED:  Set it for tomorrow morning.
# LANG:        tamil
# TRANSLATED:  நாளை காலை அதை அமைக்கவும்.
# ------------------------------------------------------------------------------------------
# INPUT:       move the meeting to next Monday
# NORMALIZED:  Let's reschedule the meeting for next Monday.
# LANG:        telugu
# TRANSLATED:  వచ్చే సోమవారం సమావేశాన్ని రీషెడ్యూల్ చేద్దాం.
# ------------------------------------------------------------------------------------------
# INPUT:       hit the sack, I'm tired
# NORMALIZED:  I'm going to bed now, I'm exhausted.
# LANG:        hindi
# TRANSLATED:  मैं अब सोने जा रहा हूँ, मैं थक गया हूँ।
#
# ####################################################################################################
# Batch 10 | cases 73-80
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       submit before 23:59 today
# NORMALIZED:  Submit it by 11:59 PM today.
# LANG:        hindi
# TRANSLATED:  इसे आज 11:59 PM तक जमा कर दें।
# ------------------------------------------------------------------------------------------
# INPUT:       We observed intermittent failures in production.
# NORMALIZED:  Intermittent failures were noticed in the production environment.
# LANG:        kannada
# TRANSLATED:  ಉತ್ಪಾದನಾ ಪರಿಸರದಲ್ಲಿ ಮಧ್ಯಂತರ ವೈಫಲ್ಯಗಳು ಕಂಡುಬಂದವು.
# ------------------------------------------------------------------------------------------
# INPUT:       I don't want a refund, I want a fix.
# NORMALIZED:  I do not want a refund; I want the issue to be resolved.
# LANG:        hindi
# TRANSLATED:  मैं धनवापसी नहीं चाहता; मैं चाहता हूं कि समस्या का समाधान हो।
# ------------------------------------------------------------------------------------------
# INPUT:       enaku OTP varala, help pannunga
# NORMALIZED:  I don't have a one true pairing, please help me.
# LANG:        tamil
# TRANSLATED:  எனக்கு ஒரு உண்மையான ஜோடி இல்லை, தயவுசெய்து எனக்கு உதவுங்கள்.
# ------------------------------------------------------------------------------------------
# INPUT:       Please escalate this to the engineering team.
# NORMALIZED:  Please forward this issue to the engineering team for further attention.
# LANG:        hindi
# TRANSLATED:  कृपया आगे ध्यान देने के लिए इस मुद्दे को इंजीनियरिंग टीम को भेजें।
# ------------------------------------------------------------------------------------------
# INPUT:       I'm on the same page as you
# NORMALIZED:  I agree with you.
# LANG:        kannada
# TRANSLATED:  ನಾನು ನಿಮ್ಮ ಮಾತನ್ನು ಒಪ್ಪುತ್ತೇನೆ.
# ------------------------------------------------------------------------------------------
# INPUT:       it works... then it doesn't...
# NORMALIZED:  It functions intermittently.
# LANG:        tamil
# TRANSLATED:  இது இடைவிடாமல் செயல்படுகிறது.
# ------------------------------------------------------------------------------------------
# INPUT:       need this done by 5 pm today
# NORMALIZED:  This needs to be completed by five o'clock this evening.
# LANG:        kannada
# TRANSLATED:  ಇದನ್ನು ಇಂದು ಸಂಜೆ ಐದು ಗಂಟೆಯೊಳಗೆ ಪೂರ್ಣಗೊಳಿಸಬೇಕಾಗಿದೆ.
#
# ####################################################################################################
# Batch 11 | cases 81-88
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       I didn't say it was not working.
# NORMALIZED:  I never claimed that it wasn't functioning.
# LANG:        hindi
# TRANSLATED:  मैंने कभी यह दावा नहीं किया कि यह काम नहीं कर रहा था।
# ------------------------------------------------------------------------------------------
# INPUT:       wow amazing service, server down again 👏
# NORMALIZED:  This service is truly impressive—yet again, the server is not working.
# LANG:        hindi
# TRANSLATED:  यह सेवा वास्तव में प्रभावशाली है-फिर भी, सर्वर काम नहीं कर रहा है।
# ------------------------------------------------------------------------------------------
# INPUT:       idk man, it's raining cats and dogs
# NORMALIZED:  I do not know, it is raining very heavily.
# LANG:        hindi
# TRANSLATED:  मुझे नहीं पता, बहुत भारी बारिश हो रही है।
# ------------------------------------------------------------------------------------------
# INPUT:       no
# NORMALIZED:  I don't understand.
# LANG:        kannada
# TRANSLATED:  ನನಗೆ ಅರ್ಥವಾಗುತ್ತಿಲ್ಲ.
# ------------------------------------------------------------------------------------------
# INPUT:       It's not that I can't login, it's that it logs me out.
# NORMALIZED:  The issue isn't that I'm unable to log in—it's that the system logs me out.
# LANG:        kannada
# TRANSLATED:  ಸಮಸ್ಯೆಯೆಂದರೆ ನನಗೆ ಲಾಗ್ ಇನ್ ಮಾಡಲು ಸಾಧ್ಯವಾಗುತ್ತಿಲ್ಲ-ಅದು ಸಿಸ್ಟಮ್ ನನ್ನನ್ನು ಲಾಗ್ ಔಟ್ ಮಾಡುತ್ತದೆ.
# ------------------------------------------------------------------------------------------
# INPUT:       thanks bhai, but issue abhi bhi hai
# NORMALIZED:  Thanks, brother, but the problem is still there.
# LANG:        hindi
# TRANSLATED:  धन्यवाद भाई, लेकिन समस्या अभी भी है।
# ------------------------------------------------------------------------------------------
# INPUT:       I can't not respond by EOD.
# NORMALIZED:  I must respond by the end of the day.
# LANG:        telugu
# TRANSLATED:  నేను రోజు చివరి నాటికి సమాధానం ఇవ్వాలి.
# ------------------------------------------------------------------------------------------
# INPUT:       yaar server firse down ho gaya
# NORMALIZED:  Friend, the server has gone down again.
# LANG:        hindi
# TRANSLATED:  दोस्त, सर्वर फिर से डाउन हो गया है।
#
# ####################################################################################################
# Batch 12 | cases 89-96
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       Please don't cancel the order.
# NORMALIZED:  Please do not cancel the order.
# LANG:        telugu
# TRANSLATED:  దయచేసి ఆర్డర్ను రద్దు చేయవద్దు.
# ------------------------------------------------------------------------------------------
# INPUT:       why??????
# NORMALIZED:  Why?
# LANG:        kannada
# TRANSLATED:  ಏಕೆ?
# ------------------------------------------------------------------------------------------
# INPUT:       whattttt is thisssss 😭😭
# NORMALIZED:  What is this? I am so upset.
# LANG:        kannada
# TRANSLATED:  ಇದು ಏನು? ನಾನು ತುಂಬಾ ಅಸಮಾಧಾನಗೊಂಡಿದ್ದೇನೆ.
# ------------------------------------------------------------------------------------------
# INPUT:       hmmm idk
# NORMALIZED:  I am not sure.
# LANG:        telugu
# TRANSLATED:  నాకు ఖచ్చితంగా తెలియదు.
# ------------------------------------------------------------------------------------------
# INPUT:       fantastic, payment failed for the third time
# NORMALIZED:  The payment has failed for the third time, which is very frustrating.
# LANG:        bengali
# TRANSLATED:  তৃতীয়বারের মতো অর্থ প্রদান ব্যর্থ হয়েছে, যা অত্যন্ত হতাশাজনক।
# ------------------------------------------------------------------------------------------
# INPUT:       call maadi, important
# NORMALIZED:  Please call me soon; it's important.
# LANG:        kannada
# TRANSLATED:  ದಯವಿಟ್ಟು ನನಗೆ ಶೀಘ್ರದಲ್ಲೇ ಕರೆ ಮಾಡಿ; ಇದು ಮುಖ್ಯವಾಗಿದೆ.
# ------------------------------------------------------------------------------------------
# INPUT:       The customer is waiting; please respond ASAP.
# NORMALIZED:  The customer is waiting; please reply as soon as possible.
# LANG:        tamil
# TRANSLATED:  வாடிக்கையாளர் காத்திருக்கிறார், தயவுசெய்து விரைவில் பதிலளிக்கவும்.
# ------------------------------------------------------------------------------------------
# INPUT:       naan late aaguren, sorry
# NORMALIZED:  I didn't mean to be late, sorry.
# LANG:        tamil
# TRANSLATED:  நான் தாமதமாக வர விரும்பவில்லை, மன்னிக்கவும்.
#
# ####################################################################################################
# Batch 13 | cases 97-104
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       bro swalpa adjust maadi, urgent ide
# NORMALIZED:  Dude, please adjust it a little, it's urgent.
# LANG:        kannada
# TRANSLATED:  ಡ್ಯೂಡ್, ದಯವಿಟ್ಟು ಅದನ್ನು ಸ್ವಲ್ಪ ಸರಿಹೊಂದಿಸಿ, ಇದು ತುರ್ತು.
# ------------------------------------------------------------------------------------------
# INPUT:       thanks for nothing
# NORMALIZED:  You were of no help at all.
# LANG:        telugu
# TRANSLATED:  మీరు అస్సలు సహాయం చేయలేదు.
# ------------------------------------------------------------------------------------------
# INPUT:       super smooth experience... said no one ever
# NORMALIZED:  A completely seamless experience is something no one has ever described.
# LANG:        kannada
# TRANSLATED:  ಸಂಪೂರ್ಣವಾಗಿ ತಡೆರಹಿತವಾದ ಅನುಭವವು ಯಾರೂ ವಿವರಿಸದ ಸಂಗತಿಯಾಗಿದೆ.
# ------------------------------------------------------------------------------------------
# INPUT:       Don't reschedule the meeting.
# NORMALIZED:  Do not change the time of the meeting.
# LANG:        tamil
# TRANSLATED:  கூட்டத்தின் நேரத்தை மாற்ற வேண்டாம்.
# ------------------------------------------------------------------------------------------
# INPUT:       urgent
# NORMALIZED:  This is urgent.
# LANG:        telugu
# TRANSLATED:  ఇది అత్యవసరం.
# ------------------------------------------------------------------------------------------
# INPUT:       lowkey I'm done with this
# NORMALIZED:  I'm subtly fed up with this.
# LANG:        marathi
# TRANSLATED:  मला या गोष्टीचा खूप कंटाळा आला आहे.
# ------------------------------------------------------------------------------------------
# INPUT:       pls thoda jaldi karo, urgent hai
# NORMALIZED:  Please do it a bit faster, it's urgent.
# LANG:        hindi
# TRANSLATED:  कृपया इसे थोड़ा जल्दी करें, यह जरूरी है।
# ------------------------------------------------------------------------------------------
# INPUT:       payment pannen but status update aagala
# NORMALIZED:  The payment failed, but the status has been updated.
# LANG:        tamil
# TRANSLATED:  பணம் செலுத்துவதில் தோல்வியுற்றது, ஆனால் நிலை புதுப்பிக்கப்பட்டுள்ளது.
#
# ####################################################################################################
# Batch 14 | cases 105-112
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       break a leg for your interview
# NORMALIZED:  Good luck with your interview.
# LANG:        bengali
# TRANSLATED:  আপনার সাক্ষাৎকারের জন্য শুভেচ্ছা রইল।
# ------------------------------------------------------------------------------------------
# INPUT:       kelsa complete madidini, pls review
# NORMALIZED:  Please complete the task quickly, and review it for me.
# LANG:        kannada
# TRANSLATED:  ದಯವಿಟ್ಟು ಕೆಲಸವನ್ನು ತ್ವರಿತವಾಗಿ ಪೂರ್ಣಗೊಳಿಸಿ ಮತ್ತು ನನಗಾಗಿ ಅದನ್ನು ಪರಿಶೀಲಿಸಿ.
# ------------------------------------------------------------------------------------------
# INPUT:       Not today, maybe tomorrow.
# NORMALIZED:  I cannot do it today, but perhaps I can do it tomorrow.
# LANG:        kannada
# TRANSLATED:  ನಾನು ಇಂದು ಅದನ್ನು ಮಾಡಲು ಸಾಧ್ಯವಿಲ್ಲ, ಆದರೆ ಬಹುಶಃ ನಾನು ಅದನ್ನು ನಾಳೆ ಮಾಡಬಹುದು.
# ------------------------------------------------------------------------------------------
# INPUT:       BROOOOOOOOOOO
# NORMALIZED:  Hey, man!
# LANG:        marathi
# TRANSLATED:  अरे यार!
# ------------------------------------------------------------------------------------------
# INPUT:       it's not my cup of tea
# NORMALIZED:  That is not something I enjoy.
# LANG:        kannada
# TRANSLATED:  ಅದು ನಾನು ಆನಂದಿಸುವ ವಿಷಯವಲ್ಲ.
# ------------------------------------------------------------------------------------------
# INPUT:       yes
# NORMALIZED:  Yes.
# LANG:        tamil
# TRANSLATED:  ஆம்.
# ------------------------------------------------------------------------------------------
# INPUT:       let's call it a day
# NORMALIZED:  Let us finish for today.
# LANG:        bengali
# TRANSLATED:  আজকের জন্য শেষ করা যাক।
# ------------------------------------------------------------------------------------------
# INPUT:       oh perfect, now it's stuck on loading forever
# NORMALIZED:  Great, now it's just loading indefinitely.
# LANG:        tamil
# TRANSLATED:  நன்றாக இருக்கிறது, இப்போது அது காலவரையின்றி ஏற்றப்படுகிறது.
#
# ####################################################################################################
# Batch 15 | cases 113-118
# ####################################################################################################
# ------------------------------------------------------------------------------------------
# INPUT:       cant login, pw reset not working
# NORMALIZED:  I can't log in, and the password reset isn't working.
# LANG:        kannada
# TRANSLATED:  ನನಗೆ ಲಾಗ್ ಇನ್ ಮಾಡಲು ಸಾಧ್ಯವಾಗುತ್ತಿಲ್ಲ ಮತ್ತು ಪಾಸ್ವರ್ಡ್ ರೀಸೆಟ್ ಕೆಲಸ ಮಾಡುತ್ತಿಲ್ಲ.
# ------------------------------------------------------------------------------------------
# INPUT:       net slow so msg late
# NORMALIZED:  The internet connection is slow, so the message is delayed.
# LANG:        bengali
# TRANSLATED:  ইন্টারনেট সংযোগ ধীর, তাই বার্তাটি বিলম্বিত হয়।
# ------------------------------------------------------------------------------------------
# INPUT:       Kindly share the RCA once available.
# NORMALIZED:  Please provide the root cause analysis as soon as it is ready.
# LANG:        tamil
# TRANSLATED:  தயவுசெய்து மூல காரண பகுப்பாய்வு தயாராக உள்ள உடனேயே வழங்கவும்.
# ------------------------------------------------------------------------------------------
# INPUT:       fr this app slaps
# NORMALIZED:  This application is excellent.
# LANG:        telugu
# TRANSLATED:  ఈ యాప్ చాలా బాగుంది.
# ------------------------------------------------------------------------------------------
# INPUT:       once in a blue moon
# NORMALIZED:  Very rarely.
# LANG:        tamil
# TRANSLATED:  மிகவும் அரிதானது.
# ------------------------------------------------------------------------------------------
# INPUT:       server down ah? romba worst
# NORMALIZED:  Is the server down? It's extremely bad.
# LANG:        tamil
# TRANSLATED:  சர்வர் செயலிழந்துவிட்டதா? இது மிகவும் மோசமானது.
#
# ✅ Finished. Results stored in: stress_results
